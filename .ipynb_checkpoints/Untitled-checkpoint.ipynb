# %%
import numpy as np

# %%
import cv2 as cv

# %%
import matplotlib.pyplot as plt

# %%
img = cv.imread('Images/MSD.jpg')

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (456, 468, 3)

# %%
print(img.size)
# Out:
# 640224

# %%
print(img.dtype)
# Out:
# uint8

# %%
b,g,r = cv.split(img)

# %%
img = cv.merge((b,g,r))

# %%
icon = img[280:340, 330:390]

# %%
img[273:333,100:160] = icon

# %%
plt.imshow(img)

# %%
img2 = cv.imread('images/MSD2.jpg')

# %%
plt.imshow(img2)

# %%
print(img2.shape)
# Out:
# (198, 254, 3)

# %%
print(img2.size)
# Out:
# 150876

# %%
print(img.shape)
# Out:
# (456, 468, 3)

# %%
print(img.size)
# Out:
# 640224

# %%
plt.imshow(img2)

# %%
resize = cv.resize(img2,(468, 456))

# %%
print(resize.size)
# Out:
# 640224

# %%
plt.imshow(resize)

# %%
print(resize.shape)
# Out:
# (456, 468, 3)

# %%
plt.imshow(resize)

# %%
#imgresize = reshape(img2, (456,468,3))
# imgresize=imgresize .reshape(( 456,468,3))

# %%
plt.imshow(resize)

# %%
Newimg = cv.add(img , resize)

# %%
plt.imshow(Newimg)

# %%
img = cv.resize(img, (512,512))

# %%
img2 = cv.resize(img2, (512,512))

# %%
dst = cv.add(img, img2)

# %%
plt.imshow(dst)

# %%
dst = cv.addWeighted(img, .9 , img2, .5, 0)

# %%
plt.imshow(dst)
